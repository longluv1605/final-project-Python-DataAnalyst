# %%
import pandas as pd
import numpy as np
import ast

# %%
cols = np.load('./Data/Final/ClashOfClans_cols.npy', allow_pickle=True)

# %%
arr = np.load('./Data/Final/ClashOfClans.npy', allow_pickle=True)

# %%
df = pd.DataFrame.from_records(arr, columns=df.columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   post_id         168 non-null    object
#  1   time            168 non-null    datetime64[ns]
#  2   timestamp       168 non-null    float64
#  3   post_text       168 non-null    object
#  4   shares          168 non-null    int64
#  5   comments        168 non-null    int64
#  6   comments_full   168 non-null    object
#  7   reaction_count  168 non-null    int64
#  8   reactions       168 non-null    object
#  9   reactors        168 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(5)
# memory usage: 13.3+ KB

# %%
df['comments_full'][0]
# Out:
# [{'comment_id': '1483156222461521',
#   'comment_url': 'https://facebook.com/1483156222461521',
#   'commenter_id': '1547348997',
#   'commenter_url': 'https://facebook.com/candi.warren?eav=AfbiNpmqys47oOcpozaaZ3-1fujQk0SS2bcFyRNYACc39Nx-5mGmYaUdXYJPithtcxw&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Candi Warren',
#   'commenter_meta': None,
#   'comment_text': 'I’m maxed out on everything…. Can you make it so I can gift resources to my own clan. Otherwise, I’m a sitting duck for attacks… I still want to enjoy the game, some how',
#   'comment_time': datetime.datetime(2023, 11, 8, 0, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': [{'comment_id': '649800960690490',
#     'comment_url': 'https://facebook.com/649800960690490',
#     'commenter_id': '100004529382881',
#     'commenter_url': 'https://facebook.com/adam.genez?eav=AfZCK-UleIF6a4cv3xxoeTM-QMa7sxHrV0MqIqNTvkhGl1tPKBfSBcfhKucQ5IYcP6I&fref=nf&rc=p&__tn__=R&paipv=0',
#     'commenter_name': 'Adam Genez',
#     'commenter_meta': None,
#     'comment_text': 'Candi Warren this is a ruled out idea for 2 reasons:\n\n1: people will create a bunch of “mini” accounts and pool their resources onto their main account\n\n2: people will create black markets and attempt to sell resources to people for real money; this is against terms of service',
#     'comment_time': datetime.datetime(2023, 11, 8, 0, 0),
#     'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfDL0NFvPSJ7sJzbMJ0FK3sxzAPxovKgphEn0FPnfjjWqg&oe=657653F9&_nc_sid=7da55a',
#     'comment_reactors': [],
#     'comment_reactions': None,
#     'comment_reaction_count': None}]},
#  {'comment_id': '317532330989943',
#   'comment_url': 'https://facebook.com/317532330989943',
#   'commenter_id': '100051419944069',
#   'commenter_url': 'https://facebook.com/profile.php?id=100051419944069&eav=AfZF-_aUfS7q3jIE22CVYM-kC6xYXAl-PE2SHWhiu3BOuajbr3Th9uI1LglLRDW-bkk&fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0',
#   'commenter_name': 'Huy Anh',
#   'commenter_meta': None,
#   'comment_text': 'đề nghị nhà phát hành game xem xét lại lỗi mất mạng là mất cả trận đấu. tôi vừa vào đánh war 7 ngày thì mất mạng ,vào thấy 0% . đề nghị nhà phát hành xem xét lại lỗi đó và phải khắc phục ngay . để trận đấu được tiếp tục ....',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfDL0NFvPSJ7sJzbMJ0FK3sxzAPxovKgphEn0FPnfjjWqg&oe=657653F9&_nc_sid=7da55a',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': [{'comment_id': '278551084605634',
#     'comment_url': 'https://facebook.com/278551084605634',
#     'commenter_id': '100064485272596',
#     'commenter_url': 'https://facebook.com/np.ngocphuc1?eav=AfYkEXswpcMIG9wJF8lkMQelueZrz7PcRzPq271vgpO_jTFimUtRBrDX2Nafa64li5E&fref=nf&rc=p&__tn__=R&paipv=0',
#     'commenter_name': 'Aurelius Aurie',
#     'commenter_meta': None,
#     'comment_text': 'Huy Anh thử dùng 1.1.1.1 lúc chơi đi\nGiải pháp hiệu quả nhất\nHoặc là mạng nhà anh rá-',
#     'comment_time': datetime.datetime(2023, 11, 8, 0, 0),
#     'comment_image': None,
#     'comment_reactors': [],
#     'comment_reactions': None,
#     'comment_reaction_count': None},
#    {'comment_id': '869826164815412',
#     'comment_url': 'https://facebook.com/869826164815412',
#     'commenter_id': '100004094897649',
#     'commenter_url': 'https://facebook.com/trinhtrung0977444380?eav=AfZpaHuMBUNG2R1ZaO7534l7-IkVTomuYzcez9SJumVL_8P8JbYtTr0CBf0_Lq-bOHQ&fref=nf&rc=p&__tn__=R&paipv=0',
#     'commenter_name': 'Trịnh Trung',
#     'commenter_meta': None,
#     'comment_text': 'Huy Anh ông đổi mạng khác, cập Nhật game. Hoặc Tải 1111 lên là đc',
#     'comment_time': datetime.datetime(2023, 11, 8, 0, 0),
#     'comment_image': None,
#     'comment_reactors': [],
#     'comment_reactions': None,
#     'comment_reaction_count': None},
#    {'comment_id': '319988070741160',
#     'comment_url': 'https://facebook.com/319988070741160',
#     'commenter_id': '100090428256818',
#     'commenter_url': 'https://facebook.com/profile.php?id=100090428256818&eav=AfYtmVABCls_Knlkhl_Q0XX-yNgjHE7DERmXLpnTLcOggaqdhyp-S-RbkWxvbRwKEbY&fref=nf&rc=p&__tn__=R&paipv=0',
#     'commenter_name': 'Minh Thiệnn',
#     'commenter_meta': None,
#     'comment_text': 'Huy Anh sắp đc 3* mất mạng😢',
#     'comment_time': datetime.datetime(2023, 11, 9, 0, 0),
#     'comment_image': None,
#     'comment_reactors': [],
#     'comment_reactions': None,
#     'comment_reaction_count': None}]},
#  {'comment_id': '766391585294578',
#   'comment_url': 'https://facebook.com/766391585294578',
#   'commenter_id': '100004968630332',
#   'commenter_url': 'https://facebook.com/Muneshchaudhary27?eav=Afb_gep-_RAjfqcpRJDtVJ0PpHqBhDmjXyz0-8jMRxs25wrLuvM_jShilgQn6pRb44M&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'MuNesh',
#   'commenter_meta': None,
#   'comment_text': 'I would definitely gonna buy it.., if this available in Nepal 😝',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/m1/v/t6/An_F9bJG7govfshSMBkvcRLcxT0jmiXVYKtr7lgH5AHgUrjjpZ1OD0xyxXYgf7arc0lWgCdrR_KN4Mg7RSN3Gm3W6Gg03N1tQ-ZXzVvFJ_KvvB4.png?ccb=10-5&oh=00_AfB-47NFVxNSNDaYZDBklIDFTlbzQOKteDUlhTQa-j4kZg&oe=65765EA7&_nc_sid=7da55a',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '713182203675966',
#   'comment_url': 'https://facebook.com/713182203675966',
#   'commenter_id': '100024020196271',
#   'commenter_url': 'https://facebook.com/Omgtamim?eav=Afa9aHTBvPtTx287tQK5uT1PMqrlOkV09BcvVlw-_p3IpjgipB1mZ1ZgRrkrrKWut2c&fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0',
#   'commenter_name': 'Ťâ M Îm',
#   'commenter_meta': None,
#   'comment_text': 'Thanks for CWL matchmaking SUPERCELL\n#Clash of clan',
#   'comment_time': datetime.datetime(2023, 11, 8, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/v/t39.30808-6/399971837_1549402895870369_1780756529560268668_n.jpg?stp=cp0_dst-jpg_e15_q65_s180x540&_nc_cat=103&ccb=1-7&_nc_sid=5f2048&efg=eyJpIjoidCJ9&_nc_ohc=siFcnRZIpewAX_UI0Fw&_nc_ht=scontent.fhan20-1.fna&oh=00_AfCxoha8Bp_luTRntzDvhdn3TwdXC5GjTCp0WIem1913Og&oe=65549831',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': [{'comment_id': '785258046741271',
#     'comment_url': 'https://facebook.com/785258046741271',
#     'commenter_id': '100080817308447',
#     'commenter_url': 'https://facebook.com/carlyxdedication?eav=AfZ6nlnOTLtApE2nSSuD0hhvazjuWhj6dA2e7-8oHjlwBEA4gESP5_C1UCP59-LdBuM&fref=nf&rc=p&__tn__=R&paipv=0',
#     'commenter_name': 'Brett Lim',
#     'commenter_meta': None,
#     'comment_text': 'Ťâ M Îm hahahaha what league are you guys in?🤣',
#     'comment_time': datetime.datetime(2023, 11, 9, 0, 0),
#     'comment_image': None,
#     'comment_reactors': [],
#     'comment_reactions': None,
#     'comment_reaction_count': None}]},
#  {'comment_id': '307605345430489',
#   'comment_url': 'https://facebook.com/307605345430489',
#   'commenter_id': '100002797914077',
#   'commenter_url': 'https://facebook.com/BukhariCheRos?eav=AfZm8LQqw4j4jMTUC1m5yQE9yLSwCogqubsqko2xBSjVine4CrjI50YyLRB-JkgljOE&fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0',
#   'commenter_name': 'Muhamad Bukhari',
#   'commenter_meta': None,
#   'comment_text': 'We need coffee comic skin for hero and troop ☺️',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/m1/v/t6/An-9fyYLftTy_Mg2cJpugh-vEVNfbtI-fVn4FNS7K-sgIMu9pT62Tb1u9Dfm-xYLtjbLQk-yVHp_IlY_4iMVYp0xLpO7sJvbxbC2OIiRxzS02cOuKEoo.png?ccb=10-5&oh=00_AfDEGWMhvpKhL3OVJHGQdeklezjU3YxWAFXzx-x0ij064A&oe=65765C58&_nc_sid=7da55a',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '2269437623447300',
#   'comment_url': 'https://facebook.com/2269437623447300',
#   'commenter_id': '100030392137982',
#   'commenter_url': 'https://facebook.com/sachintha.deraniyagala?eav=AfbtKQkktcFCq9kjgJJM_Fe_OQv-xnLLqhR9wvK6imiZRzrd3A1E-IEmixvzH5JGLrY&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Chons Khonshu',
#   'commenter_meta': None,
#   'comment_text': 'We want a movie bro,😒💔',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfDL0NFvPSJ7sJzbMJ0FK3sxzAPxovKgphEn0FPnfjjWqg&oe=657653F9&_nc_sid=7da55a',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': [{'comment_id': '335611109192248',
#     'comment_url': 'https://facebook.com/335611109192248',
#     'commenter_id': '100002374665056',
#     'commenter_url': 'https://facebook.com/donna.caseystewart?eav=AfY95KVESCDyPq5AyLmO4PwYZKi0Z-XXW2dE_3M6zyzWlrm4jcunQL0MHhR74xz8V-o&fref=nf&rc=p&__tn__=R&paipv=0',
#     'commenter_name': 'Donna-Maree Casey',
#     'commenter_meta': 'Top fan',
#     'comment_text': "Chons Khonshu I've been asking for a full length movie for years. No one from Supercell even replies.",
#     'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#     'comment_image': None,
#     'comment_reactors': [],
#     'comment_reactions': None,
#     'comment_reaction_count': None}]},
#  {'comment_id': '1087381255622433',
#   'comment_url': 'https://facebook.com/1087381255622433',
#   'commenter_id': '100086531647431',
#   'commenter_url': 'https://facebook.com/profile.php?id=100086531647431&eav=AfbLlcFMZf6z8W35etto8uJxYMeP-UV7IBmlt855bvZN5geKofPdQ1UTyoU791Dbo-A&fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0',
#   'commenter_name': 'Èrí Fé Ôlùwåsêûn',
#   'commenter_meta': 'Top fan',
#   'comment_text': 'Matchmaking indeed 😌',
#   'comment_time': datetime.datetime(2023, 11, 9, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/v/t39.30808-6/401090888_312208505006869_7947613447042516593_n.jpg?stp=cp0_dst-jpg_e15_q65_s180x540&_nc_cat=100&ccb=1-7&_nc_sid=5f2048&efg=eyJpIjoidCJ9&_nc_ohc=vUYBwW-oFMoAX_ax5DZ&_nc_ht=scontent.fhan20-1.fna&oh=00_AfArdRFCjUpgD_ciCdxHjNTrqfbo7gkNE0AEGrc1JY8RXA&oe=6553F5A1',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': [{'comment_id': '1005229323867309',
#     'comment_url': 'https://facebook.com/1005229323867309',
#     'commenter_id': '100001134435988',
#     'commenter_url': 'https://facebook.com/paras.shrestha2?eav=Afb47gAC9kXfOdw-rBucPTFL9NuiCRNnT8GmhS0458PRUuIWtlxo2q0LJpv9NsDQcJA&fref=nf&rc=p&__tn__=R&paipv=0',
#     'commenter_name': 'Paras Shrestha',
#     'commenter_meta': 'Top fan',
#     'comment_text': 'Èrí Fé Ôlùwåsêûn is it a bug its still struck even after cwl ended!',
#     'comment_time': datetime.datetime(2023, 11, 10, 3, 0),
#     'comment_image': None,
#     'comment_reactors': [],
#     'comment_reactions': None,
#     'comment_reaction_count': None},
#    {'comment_id': '351305447580529',
#     'comment_url': 'https://facebook.com/351305447580529',
#     'commenter_id': '100086531647431',
#     'commenter_url': 'https://facebook.com/profile.php?id=100086531647431&eav=Afb-yc9FuWsaDFhpy1N0EiGqLEwWfbvEs89xJuc9V7AHgKWh0A7CkIHws1677a6xxco&fref=nf&rc=p&__tn__=%7ER&paipv=0',
#     'commenter_name': 'Èrí Fé Ôlùwåsêûn',
#     'commenter_meta': 'Top fan',
#     'comment_text': "Paras Shrestha no it's still on the 6th day after I clicked on the 7th day",
#     'comment_time': datetime.datetime(2023, 11, 10, 9, 0),
#     'comment_image': None,
#     'comment_reactors': [],
#     'comment_reactions': None,
#     'comment_reaction_count': None}]},
#  {'comment_id': '1276829083004249',
#   'comment_url': 'https://facebook.com/1276829083004249',
#   'commenter_id': '100005273238722',
#   'commenter_url': 'https://facebook.com/DeadlyNightOwl?eav=AfZgsl5abmv5IHQtMmElFsfJN-5agw6g0hOVbvQxkvdDyWAeogMgU_GMB9Ot9VTKCh4&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Kaile Griffiths-Hinsch',
#   'commenter_meta': None,
#   'comment_text': 'When can we use this twice a day',
#   'comment_time': datetime.datetime(2023, 11, 9, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/v/t39.30808-6/400033829_2358597447659340_558491422085264909_n.jpg?stp=cp0_dst-jpg_e15_q65_s180x540&_nc_cat=109&ccb=1-7&_nc_sid=5f2048&efg=eyJpIjoidCJ9&_nc_ohc=PazXCIRjPIIAX9UMD7k&_nc_ht=scontent.fhan20-1.fna&oh=00_AfBEAezOzYqF3KadUIrliVelGSel8X15ji6BGBpL8SBZ1g&oe=655368B7',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '578775061041497',
#   'comment_url': 'https://facebook.com/578775061041497',
#   'commenter_id': '100087330579088',
#   'commenter_url': 'https://facebook.com/profile.php?id=100087330579088&eav=AfY86LcJVG2QXfhcxS17rUssKSnLCU5b5cYSljqg4AD26C4rMJCfmJuQfKSwULrM6vE&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Prajapati Kumar Anuj',
#   'commenter_meta': None,
#   'comment_text': 'Please this region available in Nepal🇳🇵🇳🇵',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/m1/v/t6/An_F9bJG7govfshSMBkvcRLcxT0jmiXVYKtr7lgH5AHgUrjjpZ1OD0xyxXYgf7arc0lWgCdrR_KN4Mg7RSN3Gm3W6Gg03N1tQ-ZXzVvFJ_KvvB4.png?ccb=10-5&oh=00_AfB-47NFVxNSNDaYZDBklIDFTlbzQOKteDUlhTQa-j4kZg&oe=65765EA7&_nc_sid=7da55a',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': [{'comment_id': '3427783804200722',
#     'comment_url': 'https://facebook.com/3427783804200722',
#     'commenter_id': '100016676897455',
#     'commenter_url': 'https://facebook.com/profile.php?id=100016676897455&eav=Afa0Qv87uesjqCehUQ_zjkEsm-9TC7naFodzPVKbUwLzlr5K8WTOxHX9I1TjT_ZXU_M&fref=nf&rc=p&__tn__=%7ER&paipv=0',
#     'commenter_name': 'Đậu Văn Trân',
#     'commenter_meta': None,
#     'comment_text': 'Prajapati Kumar Anuj hello nepal 😂',
#     'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#     'comment_image': None,
#     'comment_reactors': [],
#     'comment_reactions': None,
#     'comment_reaction_count': None}]},
#  {'comment_id': '1331035421117286',
#   'comment_url': 'https://facebook.com/1331035421117286',
#   'commenter_id': '100003222895189',
#   'commenter_url': 'https://facebook.com/ruzcelbeltran?eav=AfZHe2Bic4yqHUObucKOUI5Xk_ZY_VNvcyzGnjHEPFL4bnmLF5mTlazzMOP0-59Etpk&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Beltran Sarreal Ruzcel',
#   'commenter_meta': 'Top fan',
#   'comment_text': "Wow amazing I haven't read my volume one yet haha",
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/v/t39.30808-6/400425213_6874511189332909_6412393342729730896_n.jpg?stp=cp0_dst-jpg_e15_p110x80_q65&_nc_cat=103&ccb=1-7&_nc_sid=5f2048&efg=eyJpIjoidCJ9&_nc_ohc=GduLdfrMdFQAX9HNomP&tn=uz-Z8SUi9UsoTCxk&_nc_ht=scontent.fhan20-1.fna&oh=00_AfDGidn27V5k0BsnibUtzzmgpOaYdI-hZp3qi7EEK1v2Og&oe=6554D9E1',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '24934653822800112',
#   'comment_url': 'https://facebook.com/24934653822800112',
#   'commenter_id': '1623913982',
#   'commenter_url': 'https://facebook.com/gary.maltby.10?eav=Afak-Dk1UY3tZFUbUGIMvLGs6_nlnDSEJBS38_zPNVqoPNp7Vf_YJsRvoJFLjvi6tIQ&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Gary Maltby',
#   'commenter_meta': None,
#   'comment_text': 'Let’s get some cool war scenery’s ..the Roman Stadium is awesome but ridiculous cost…take 6 months to get it.',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfDL0NFvPSJ7sJzbMJ0FK3sxzAPxovKgphEn0FPnfjjWqg&oe=657653F9&_nc_sid=7da55a',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '1043204256883171',
#   'comment_url': 'https://facebook.com/1043204256883171',
#   'commenter_id': '100047427937687',
#   'commenter_url': 'https://facebook.com/ken.usero.1?eav=AfZ92O6M-bbGXxPviqmgyRlEf3hiBxyK_bu1zdrS5dmGC4PFFq3v5iv3wNHwSwGmcFU&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'John Kenneth S. Usero',
#   'commenter_meta': None,
#   'comment_text': 'Please make legendary skin champion RC',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfDL0NFvPSJ7sJzbMJ0FK3sxzAPxovKgphEn0FPnfjjWqg&oe=657653F9&_nc_sid=7da55a',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '208792368912021',
#   'comment_url': 'https://facebook.com/208792368912021',
#   'commenter_id': '100002000020992',
#   'commenter_url': 'https://facebook.com/Rizal.suryana?eav=AfYgQvPiJ4aE_s-qfpNDiMcztiNLl5yzeWlHQruS61CfPT97y3g7dZaOKDfnB4ldbuM&fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0',
#   'commenter_name': 'Rizal Suryana',
#   'commenter_meta': 'Top fan',
#   'comment_text': 'Resale goblin skin please',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '1015294779728674',
#   'comment_url': 'https://facebook.com/1015294779728674',
#   'commenter_id': '100049983520993',
#   'commenter_url': 'https://facebook.com/sabbinhasan.asik?eav=AfZEWsKWUx3_Z19fCkcKiw8rUYqw0EibT4ou7RycAeOL9sxQ8rz_uBknB4nsg4aBnxM&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'SAbbin Hasan',
#   'commenter_meta': None,
#   'comment_text': 'Need some player\n#29J8G9CRC',
#   'comment_time': datetime.datetime(2023, 11, 10, 9, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '1422162148514105',
#   'comment_url': 'https://facebook.com/1422162148514105',
#   'commenter_id': '100025223529184',
#   'commenter_url': 'https://facebook.com/profile.php?id=100025223529184&eav=Afam09_wT4NmF7BcLiOgV_eHgC-du5GonHRzj8ckd0X4CQirHmLuUa8DynZvnZN1V4A&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'MD Azizul Hakim',
#   'commenter_meta': None,
#   'comment_text': '🇧🇩',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/m1/v/t6/An_F9bJG7govfshSMBkvcRLcxT0jmiXVYKtr7lgH5AHgUrjjpZ1OD0xyxXYgf7arc0lWgCdrR_KN4Mg7RSN3Gm3W6Gg03N1tQ-ZXzVvFJ_KvvB4.png?ccb=10-5&oh=00_AfB-47NFVxNSNDaYZDBklIDFTlbzQOKteDUlhTQa-j4kZg&oe=65765EA7&_nc_sid=7da55a',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '657182529734954',
#   'comment_url': 'https://facebook.com/657182529734954',
#   'commenter_id': '100009271578217',
#   'commenter_url': 'https://facebook.com/noelnaz15?eav=AfYVQ0eUsX3jMXlrNUnh9ZFQFxKX5Ln1ZvIAfGaDlZ7Gc0tvF0Pja4eMlmM5U12OU9Y&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Noel L. Naz',
#   'commenter_meta': 'Top fan',
#   'comment_text': 'Checking top Fan badge. Hahahaha',
#   'comment_time': datetime.datetime(2023, 11, 8, 0, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '667858648492981',
#   'comment_url': 'https://facebook.com/667858648492981',
#   'commenter_id': '100075624829520',
#   'commenter_url': 'https://facebook.com/anders.delulu?eav=AfbIpxlKLuO7cXykkwu7Zeh6ASe1llqi90cXjBHwqRtp3aDYMO4R37e3XcrzK12l-xg&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Andrei ʚìɞ Mendozaʚíɞ',
#   'commenter_meta': 'Top fan',
#   'comment_text': 'please revamp the old hero skins',
#   'comment_time': datetime.datetime(2023, 11, 8, 0, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '856401429287451',
#   'comment_url': 'https://facebook.com/856401429287451',
#   'commenter_id': '100000057577736',
#   'commenter_url': 'https://facebook.com/hi.stranger.heIIo?eav=AfYXILbWY7k9LybusrgmZtY5dYEnWbtpN3vesW_yQPBHgQU6an68RFc_V_Z1WDlBXq0&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Otama Guava',
#   'commenter_meta': None,
#   'comment_text': 'Book of clash scenery is lit.',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '1313384932641727',
#   'comment_url': 'https://facebook.com/1313384932641727',
#   'commenter_id': '100082544773710',
#   'commenter_url': 'https://facebook.com/profile.php?id=100082544773710&eav=AfZec6Ox6XGWTuVkEiq1aOye83yfX2VjkZzLWPNjkImbFq1DQdzpQZ161-VMo_VKiVg&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Randall Earwood',
#   'commenter_meta': None,
#   'comment_text': "Clash of Clans I'm surprised y'all didn't even the league out little better .. especially when I'm getting mainly th15s to attack and I'm only th13..",
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '361058366452782',
#   'comment_url': 'https://facebook.com/361058366452782',
#   'commenter_id': '100008762550962',
#   'commenter_url': 'https://facebook.com/profile.php?id=100008762550962&eav=Afbb8_GwkV1DdVei-iJTCXVqq5qFVaumB3QL-tSFpZR24GTboQ5KYVb5AiAH5-IJ2R0&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Văn Đạt',
#   'commenter_meta': None,
#   'comment_text': '#2G92CC8R9 mời vào hội mình nhé aem :))',
#   'comment_time': datetime.datetime(2023, 11, 9, 0, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '700470088683270',
#   'comment_url': 'https://facebook.com/700470088683270',
#   'commenter_id': '100003477970616',
#   'commenter_url': 'https://facebook.com/rath.valentine.1?eav=AfapKP4rvs5EytTxWwIv9SbMwBfNG6-xtWfzW0PBpXz2uxl9QShO8fvK6TZSGvnNwlw&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Sky Walker',
#   'commenter_meta': None,
#   'comment_text': 'Vol 2 skin is the same Vol 1?',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '172726389244444',
#   'comment_url': 'https://facebook.com/172726389244444',
#   'commenter_id': '100015092894150',
#   'commenter_url': 'https://facebook.com/profile.php?id=100015092894150&eav=AfY_i91gbJGin8kkeNuLEWkWfeqf-gHH2t3mwR-rAkPlnQnatHkN1GMBWmPPOK4j4IA&fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0',
#   'commenter_name': 'Tajul Islam Ctg',
#   'commenter_meta': None,
#   'comment_text': '#Bangladesh',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '901921834884845',
#   'comment_url': 'https://facebook.com/901921834884845',
#   'commenter_id': '100047123186843',
#   'commenter_url': 'https://facebook.com/nax.2312?eav=Afb10Ojrqrch4srG-iZZq8iPveEKJz-HJy7fO1EnYnR2zu1gJ5-WC0JbOHg2cYSvZ9E&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Nguyễn Duy Nam',
#   'commenter_meta': 'Top fan',
#   'comment_text': 'ez fan cứng',
#   'comment_time': datetime.datetime(2023, 11, 9, 0, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '2398707996992431',
#   'comment_url': 'https://facebook.com/2398707996992431',
#   'commenter_id': '100027634570476',
#   'commenter_url': 'https://facebook.com/mdmusaislam.musa.169?eav=AfZTNzK-toZglzY6WdGRk6ur-CzjP-QDXBxgcXivFlqqHKTvzMAtxVezJ91J3PZM-4E&fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0',
#   'commenter_name': 'Md. Musa Islam',
#   'commenter_meta': 'Top fan',
#   'comment_text': '🚀',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '695638562673074',
#   'comment_url': 'https://facebook.com/695638562673074',
#   'commenter_id': '100013217710210',
#   'commenter_url': 'https://facebook.com/profile.php?id=100013217710210&eav=Afb5QREizkdJfXM3fL4lmOW-lQ4XRWtSVusxqMIAHDqG0JthOXnZgxEsm3ofqVQ_-QE&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Yelena Antônia',
#   'commenter_meta': None,
#   'comment_text': "I've been contacting support since last week and they haven't responded. I spent some time without playing and when I entered my village I realized that someone else was accessing it. In short, someone changed the Supercell ID login email. Before I could get in and now I can't even do that anymore. He changed the name of the village from Hera to Avocado! I WANT MY VILLAGE! 😠",
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfDL0NFvPSJ7sJzbMJ0FK3sxzAPxovKgphEn0FPnfjjWqg&oe=657653F9&_nc_sid=7da55a',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': [{'comment_id': '701020271683996',
#     'comment_url': 'https://facebook.com/701020271683996',
#     'commenter_id': '100013217710210',
#     'commenter_url': 'https://facebook.com/profile.php?id=100013217710210&eav=AfZMpy__6oDXCY8PooCpfwjudI9oJ28k3n9fdy_k48xuke_1ZYUlyAEme6P7NQ6xzeI&fref=nf&rc=p&__tn__=R&paipv=0',
#     'commenter_name': 'Yelena Antônia',
#     'commenter_meta': None,
#     'comment_text': 'Oli Chris Thanks 🤝',
#     'comment_time': datetime.datetime(2023, 11, 8, 0, 0),
#     'comment_image': None,
#     'comment_reactors': [],
#     'comment_reactions': None,
#     'comment_reaction_count': None}]},
#  {'comment_id': '1119088525926697',
#   'comment_url': 'https://facebook.com/1119088525926697',
#   'commenter_id': '100076251129257',
#   'commenter_url': 'https://facebook.com/HAMAKURDISH8?eav=AfbtXM0-vluhYbiSEJEJVJg_TGhFTvx8x0MHBDZE1NAq_6r8R_kuYqFoCZkXRBGyQ9g&fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0',
#   'commenter_name': 'HAMA KURD COC',
#   'commenter_meta': None,
#   'comment_text': 'Remember your first Supercell Gold Pass?\n\nhow many people have this skin',
#   'comment_time': datetime.datetime(2023, 11, 9, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/v/t39.30808-6/400989572_357505723467796_5947846879650197706_n.jpg?stp=cp0_dst-jpg_e15_q65_s180x540&_nc_cat=107&ccb=1-7&_nc_sid=5f2048&efg=eyJpIjoidCJ9&_nc_ohc=Um_xUMBp5MkAX8-NI9z&_nc_ht=scontent.fhan20-1.fna&oh=00_AfANpHVWe1quc5I7Qi3VIJTvPa3YcuIUtyHn51vsAiW-NQ&oe=6554022D',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '1158479908308488',
#   'comment_url': 'https://facebook.com/1158479908308488',
#   'commenter_id': '100002721973505',
#   'commenter_url': 'https://facebook.com/jheydhanlegisma?eav=AfbwzabdMj2nEmtstLN64f3x7-AxMbZlT44lkvS_BOBreQG34NaY4E6Hmxuwdaihecs&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Dann Castro Legisma III',
#   'commenter_meta': None,
#   'comment_text': 'Please fix the issue of buying goldpass. I talk to many agent on your support group. And i gave all they need. But until now nothing happen.',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfDL0NFvPSJ7sJzbMJ0FK3sxzAPxovKgphEn0FPnfjjWqg&oe=657653F9&_nc_sid=7da55a',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '863234028544034',
#   'comment_url': 'https://facebook.com/863234028544034',
#   'commenter_id': '100023573763491',
#   'commenter_url': 'https://facebook.com/kyawwana.tun.52?eav=AfY0XxBalHWD4pap1ZykwlXu0Vw-ES3EFvo0289S9q9JhxO6jCBGyoyZKZT_WrM8-o4&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Kyaw Wana Tun',
#   'commenter_meta': None,
#   'comment_text': 'Why my Facebook account not appear in your application?\nPlease tell me how to connect\nmy Facebook account with this game.',
#   'comment_time': datetime.datetime(2023, 11, 8, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/v/t39.30808-6/400039912_1494556378006807_8355027941807184316_n.jpg?stp=cp1_dst-jpg_e15_q65_s180x540&_nc_cat=104&ccb=1-7&_nc_sid=5f2048&efg=eyJpIjoidCJ9&_nc_ohc=EHApZpWd4zIAX_zBQkw&_nc_ht=scontent.fhan20-1.fna&oh=00_AfBVZxVNaxOz_ideeqmUGmdhlbpga0a6yaIIcHb75zs1ew&oe=6553206A',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': [{'comment_id': '240899712074953',
#     'comment_url': 'https://facebook.com/240899712074953',
#     'commenter_id': '100004529382881',
#     'commenter_url': 'https://facebook.com/adam.genez?eav=AfZQOamO58y7Du09fDOsbz1XHPfr4AdRpVF1_bXXMukmfHm4dRrxs-5HnexkmzcpB68&fref=nf&rc=p&__tn__=R&paipv=0',
#     'commenter_name': 'Adam Genez',
#     'commenter_meta': None,
#     'comment_text': 'Kyaw Wana Tun Facebook connectivity was removed months ago. Supercell sent an email saying it was gonna be removed & that you need to connect to Supercell ID which you did not do. Now your account is gone forever',
#     'comment_time': datetime.datetime(2023, 11, 8, 0, 0),
#     'comment_image': None,
#     'comment_reactors': [],
#     'comment_reactions': None,
#     'comment_reaction_count': None}]},
#  {'comment_id': '805510461262555',
#   'comment_url': 'https://facebook.com/805510461262555',
#   'commenter_id': '100004720262982',
#   'commenter_url': 'https://facebook.com/AhmadAbbaXi007?eav=Afaqt8-rCu8S9IyThBLLQ-8p6KLKkBsfWNbxrJQnKa5-_M3Q9xCe9IBnKkBKkoZkmpM&fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0',
#   'commenter_name': 'احمد عباسی \U000f188f',
#   'commenter_meta': None,
#   'comment_text': 'Fix this error',
#   'comment_time': datetime.datetime(2023, 11, 7, 0, 0),
#   'comment_image': 'https://scontent.fhan20-1.fna.fbcdn.net/v/t39.30808-6/400811325_2534962586671059_2359576477485350542_n.jpg?stp=cp0_dst-jpg_e15_q65_s180x540&_nc_cat=107&ccb=1-7&_nc_sid=5f2048&efg=eyJpIjoidCJ9&_nc_ohc=_mGY9M_twYUAX8Os90l&_nc_ht=scontent.fhan20-1.fna&oh=00_AfAjPfXkGJxBjtCWgCyY-gNRTSvje8I_zLGAKFgyBrpEMQ&oe=6554E8EB',
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '775402841017975',
#   'comment_url': 'https://facebook.com/775402841017975',
#   'commenter_id': '100061952933332',
#   'commenter_url': 'https://facebook.com/nasir.bhutta.75470?eav=AfYYEM6kUAK6XR4ALEmYiu7vq7UB7o1IuEBgU9tn3OmvkZy-PnpKrOGuk96KetbTAEg&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Nasir Bhutta',
#   'commenter_meta': None,
#   'comment_text': 'I need th15 id',
#   'comment_time': datetime.datetime(2023, 11, 9, 0, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []}]
