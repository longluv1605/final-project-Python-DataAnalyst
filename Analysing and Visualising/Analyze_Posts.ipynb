# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
cols = np.load('../Data/Final/ClashOfClans_cols.npy', allow_pickle=True)
arr = np.load('../Data/Final/ClashOfClans.npy', allow_pickle=True)
df = pd.DataFrame(arr, columns=cols)

# %%
df = df[['post_id', 'time', 'post_text', 
            'images_description', 'shares', 'comments',
                'comments_full', 'reaction_count',
                'reactions', 'reactors']]

# %%
df_text = df[['post_id','post_text', 'images_description']]
print(df_text.info())
df_text
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   post_id             167 non-null    object
#  1   post_text           167 non-null    object
#  2   images_description  167 non-null    object
# dtypes: object(3)
# memory usage: 4.0+ KB
# None
#               post_id                                          post_text  \
# 0     890116715803522  Books of Clash Vol 2 is on sale! 🎉 Get it now ...
# 1     889593269189200  edit: the issues have been fixed, thanks for y...
# 2     889556962526164  Hey Chief! We've got a brief maintenance happe...
# 3     888646695950524  Before Barcher, Hog Wizard, Witch Golem and La...
# 4     888172002664660
# ..                ...                                                ...
# 162  6340880625936207  Hey Chiefs! We've got some balance changes we'...
# 163  6337372302953706  Season's greetings from your friendly neighbor...
# 164  6323016887722581  Get yourself into the Clashmas mood with some ...
# 165  6319757081381895  Hey Chief! We'll take a maintenance break in ~...
# 166  6311032642254339  UPDATE DAY is here! 🤩 Maintenance will start s...
#
#                                     images_description
# 0                            [May be an image of text]
# 1                                                   []
# 2    [May be an image of text that says 'MAINTENANC...
# 3    [May be an image of text, May be an image of t...
# 4                        [May be an image of 1 person]
# ..                                                 ...
# 162                  [No photo description available.]
# 163                  [No photo description available.]
# 164                  [No photo description available.]
# 165                  [No photo description available.]
# 166                  [No photo description available.]
#
# [167 rows x 3 columns]

# %%
all_text = np.array(df_text['post_text'])
text = ''
for post in all_text:
    text += post + ' '

# %%
from wordcloud import WordCloud, STOPWORDS

wordcloud = WordCloud(stopwords=STOPWORDS,
                          background_color='white', 
                      max_words=300,
                      width=2000, height=1200
                         ).generate(text)
plt.figure(figsize=(40,20))
plt.clf()
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
